# %%
import soundfile as sf
import numpy as np
from scipy.signal import lfilter
from pydub import AudioSegment
from pydub import AudioSegment
from pydub.playback import play
import pygame
import time

def obtener_duracion_audio(ruta_archivo):
    audio = AudioSegment.from_file(ruta_archivo)
    duracion_ms = len(audio)
    duracion_seg = duracion_ms / 1000
    return duracion_seg

def calculate_snr(audio):
    # Calcular la relación señal a ruido (SNR)
    audio, sample_rate = sf.read(audio)
    signal_power = np.sum(audio ** 2)
    noise_power = np.sum(lfilter([1], [1, -0.99], audio) ** 2)
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

def calculate_thd(audio):
    # Calcular la distorsión armónica total (THD)
    audiop, sample_rate = sf.read(audio)
    fundamental = np.max(audiop)
    harmonics = np.sqrt(np.sum(audiop ** 2)) - np.abs(fundamental)
    thd = 20 * np.log10(harmonics / fundamental)
    return thd

def promedio_potencia(audio_path):
    audio, sample_rate = sf.read(audio_path)
    energy = np.sum(audio ** 2) / len(audio)
    pms = 10 * np.log10(energy)
    return pms

def nivel_peak(audio_path):
    audio, sr = sf.read(audio_path)
    # Calcular el nivel de peak
    peak = 20 * np.log10(np.max(np.abs(audio)))
    return peak
    # Calcular la relación señal a ruido (SNR)
    #snr = calculate_snr(audio)

    # Calcular la distorsión armónica total (THD)
    #thd = calculate_thd(audio)

    # Imprimir los resultados
    #print("Promedio de nivel de potencia (PMS): ", pms)
    #print("Nivel de pico: ", peak)
    #print("Relación señal a ruido (SNR): ", snr)
    #print("Distorsión armónica total (THD): ", thd)
# Out:
# pygame 2.4.0 (SDL 2.26.4, Python 3.8.16)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
def evaluar_audio(a):
    if calculate_snr(a)>-3: #descarta risas de fondo de MELD (ruido)
        return False
    if calculate_thd(a)<29: #quita sonidos
        return False
    if promedio_potencia(a)<-53: #mide promedio de volumen
        return False
    if nivel_peak(a)<-35: #mide volumen maximo
        return False
    if obtener_duracion_audio(a)< 0.8: #quita audios cortos
        return False
    # Si todos los criterios se cumplen, el audio es de buena calidad
    return True

# %%
import os
directorio_inicial1 = r"D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW"
archivos1=[]
duracion_a=[]
pasa=[]
pic=[]
mean_pot=[]
relacion_sr=[]
distorcion_armonicaT=[]
archi=[]
for raiz, carpetas, archivos_en_carpeta in os.walk(directorio_inicial1):
    for archivo in archivos_en_carpeta:
        archi.append(archivo)
        if os.path.isfile(os.path.join(raiz, archivo)):
            ruta_completa1 = os.path.join(raiz, archivo)
            archivos1.append(ruta_completa1)
            duracion = obtener_duracion_audio(ruta_completa1)
            prom_pot = promedio_potencia(ruta_completa1)
            peak = nivel_peak(ruta_completa1)
            rsr= calculate_snr(ruta_completa1)
            dat=calculate_thd(ruta_completa1)
            mean_pot.append(prom_pot)
            pic.append(peak)
            relacion_sr.append(rsr)
            distorcion_armonicaT.append(dat)
            duracion_a.append(duracion)
            if(evaluar_audio(ruta_completa1)):
                pasa.append(1)
            else:
                pasa.append(0)

# %%
import pandas as pd
#Real
archiv={"RutaArchivo": archivos1}
df= pd.DataFrame(archiv)
df["Nombre archivo"] = archi
df["duracion"] = duracion_a
df["Promedio level pot"] = mean_pot
df["Nivel peak"] = pic
df["Distorsión armónica total"] = distorcion_armonicaT
df["Relación señal a ruido"] = relacion_sr
df["Filtro"] = pasa
df
# Out:
#                                             RutaArchivo Nombre archivo  \
# 0     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000029301.wav
# 1     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000046280.wav
# 2     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000059880.wav
# 3     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000102534.wav
# 4     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000141494.wav
# ...                                                 ...            ...
# 1151  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015145521.wav
# 1152  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015238600.wav
# 1153  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015626280.wav
# 1154  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015646720.wav
# 1155  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  021837840.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0        2.448          -26.925982  -13.179254                  36.456134
# 1        3.888          -32.735003  -18.008946                  38.684294
# 2        1.920          -35.309039  -21.557158                  35.378896
# 3        2.496          -33.410550  -19.041751                  36.274271
# 4        3.048          -32.634227  -21.347245                  40.629692
# ...        ...                 ...         ...                        ...
# 1151     4.056          -35.648422  -20.992422                  41.414802
# 1152     2.928          -47.447955  -25.659241                  29.019201
# 1153     3.096          -38.485362  -22.614764                  35.334409
# 1154     2.040          -37.083908  -22.043003                  35.543562
# 1155     3.096          -32.157792  -18.205053                  37.281666
#
#       Relación señal a ruido  Filtro
# 0                  -3.733383       1
# 1                  -3.522599       1
# 2                  -3.944569       1
# 3                  -3.878937       1
# 4                  -3.941288       1
# ...                      ...     ...
# 1151               -3.855075       1
# 1152               -3.944673       1
# 1153               -3.944595       1
# 1154               -3.944599       1
# 1155               -3.942387       1
#
# [1156 rows x 8 columns]

# %%
# Evaluar si los valores de las columnas cumplen con la condición utilizando un OR
condicion1 = df['duracion'] < 0.8
condicion2 = df['Promedio level pot'] <-53
condicion3 = df['Nivel peak'] <-35
condicion4 = df['Distorsión armónica total'] <29
condicion5 = df['Relación señal a ruido'] > -3

# Contar cuántas columnas cumplen con las condiciones para cada fila
df['Falla en'] = pd.concat([condicion1, condicion2, condicion3, condicion4, condicion5], axis=1).sum(axis=1)
df
# Out:
#                                             RutaArchivo Nombre archivo  \
# 0     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000029301.wav
# 1     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000046280.wav
# 2     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000059880.wav
# 3     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000102534.wav
# 4     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000141494.wav
# ...                                                 ...            ...
# 1151  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015145521.wav
# 1152  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015238600.wav
# 1153  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015626280.wav
# 1154  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015646720.wav
# 1155  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  021837840.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0        2.448          -26.925982  -13.179254                  36.456134
# 1        3.888          -32.735003  -18.008946                  38.684294
# 2        1.920          -35.309039  -21.557158                  35.378896
# 3        2.496          -33.410550  -19.041751                  36.274271
# 4        3.048          -32.634227  -21.347245                  40.629692
# ...        ...                 ...         ...                        ...
# 1151     4.056          -35.648422  -20.992422                  41.414802
# 1152     2.928          -47.447955  -25.659241                  29.019201
# 1153     3.096          -38.485362  -22.614764                  35.334409
# 1154     2.040          -37.083908  -22.043003                  35.543562
# 1155     3.096          -32.157792  -18.205053                  37.281666
#
#       Relación señal a ruido  Filtro  Falla en
# 0                  -3.733383       1         0
# 1                  -3.522599       1         0
# 2                  -3.944569       1         0
# 3                  -3.878937       1         0
# 4                  -3.941288       1         0
# ...                      ...     ...       ...
# 1151               -3.855075       1         0
# 1152               -3.944673       1         0
# 1153               -3.944595       1         0
# 1154               -3.944599       1         0
# 1155               -3.942387       1         0
#
# [1156 rows x 9 columns]

# %%
conteo = df['Filtro'].value_counts()
print(conteo)
# Out:
# 1    1052
# 0     104
# Name: Filtro, dtype: int64

# %%
df_fallas = df[df['Filtro'] == 0].copy()
df_buenas = df[df['Filtro'] == 1].copy()

# %%
df.describe()
# Out:
#           duracion  Promedio level pot   Nivel peak  \
# count  1156.000000         1156.000000  1156.000000
# mean      2.458131          -37.937733   -23.195993
# std       1.017441            5.645960     4.995665
# min       0.408000          -69.602472   -51.720620
# 25%       1.656000          -41.165058   -25.559387
# 50%       2.280000          -37.510562   -22.515054
# 75%       3.096000          -34.216838   -20.120916
# max       6.216000          -20.837989    -8.837564
#
#        Distorsión armónica total  Relación señal a ruido       Filtro  \
# count                1156.000000             1156.000000  1156.000000
# mean                   35.631484               -3.797203     0.910035
# std                     3.092235                0.332255     0.286256
# min                    24.005381               -4.064787     0.000000
# 25%                    33.766687               -3.943060     1.000000
# 50%                    35.873797               -3.929069     1.000000
# 75%                    37.794593               -3.826221     1.000000
# max                    43.753973               -0.146588     1.000000
#
#           Falla en
# count  1156.000000
# mean      0.115052
# std       0.407397
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       3.000000

# %%
duracion_df = df_fallas[df_fallas['duracion'] < 0.8].copy()
conteos = duracion_df['Filtro'].value_counts()
print(conteos)
duracion_df
# Out:
# 0    16
# Name: Filtro, dtype: int64
#                                             RutaArchivo Nombre archivo  \
# 85    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001113440.wav
# 138   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001821420.wav
# 194   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002516934.wav
# 273   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003316894.wav
# 428   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004924334.wav
# 621   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011603980.wav
# 708   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012943150.wav
# 754   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  014643120.wav
# 781   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000322047.wav
# 786   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000403327.wav
# 829   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001130680.wav
# 849   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001703120.wav
# 952   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004512014.wav
# 955   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004524480.wav
# 1031  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010320007.wav
# 1148  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  014735000.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 85       0.768          -28.277904  -15.595424                  32.409875
# 138      0.528          -31.030312  -20.400887                  32.845620
# 194      0.744          -34.882149  -23.040520                  34.093665
# 273      0.696          -30.668156  -20.473363                  34.513765
# 428      0.768          -29.888349  -19.904570                  35.885761
# 621      0.408          -33.261932  -22.465616                  32.241188
# 708      0.624          -32.535602  -19.535011                  31.993382
# 754      0.768          -48.662410  -32.865873                  29.217677
# 781      0.696          -24.535419  -12.569038                  33.663542
# 786      0.624          -38.134963  -24.284057                  30.283557
# 829      0.696          -34.125034  -22.969339                  33.533733
# 849      0.768          -35.799578  -20.540805                  29.761421
# 952      0.768          -33.915620  -20.588895                  31.749591
# 955      0.624          -47.083112  -37.906278                  36.664026
# 1031     0.696          -29.187971  -19.774461                  35.543299
# 1148     0.480          -45.232372  -37.906278                  36.026738
#
#       Relación señal a ruido  Filtro  Falla en
# 85                 -3.426222       0         1
# 138                -4.011207       0         1
# 194                -3.887955       0         1
# 273                -3.300974       0         1
# 428                -3.897001       0         1
# 621                -3.818926       0         1
# 708                -3.478240       0         1
# 754                -3.896165       0         1
# 781                -3.723561       0         1
# 786                -3.942433       0         1
# 829                -3.788783       0         1
# 849                -3.892395       0         1
# 952                -3.822011       0         1
# 955                -2.739580       0         3
# 1031               -3.554140       0         1
# 1148               -3.475304       0         2

# %%
duracion_df.describe()
# Out:
#         duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# count  16.000000           16.000000   16.000000                  16.000000
# mean    0.666000          -34.826305  -23.176276                  33.151678
# std     0.111714            6.867918    7.135799                   2.264582
# min     0.408000          -48.662410  -37.906278                  29.217677
# 25%     0.624000          -36.383424  -23.351404                  31.932434
# 50%     0.696000          -33.588776  -20.564850                  33.189676
# 75%     0.768000          -30.473204  -19.872043                  34.771148
# max     0.768000          -24.535419  -12.569038                  36.664026
#
#        Relación señal a ruido  Filtro   Falla en
# count               16.000000    16.0  16.000000
# mean                -3.665931     0.0   1.187500
# std                  0.326770     0.0   0.543906
# min                 -4.011207     0.0   1.000000
# 25%                 -3.893338     0.0   1.000000
# 50%                 -3.803855     0.0   1.000000
# 75%                 -3.477506     0.0   1.000000
# max                 -2.739580     0.0   3.000000

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

column_data = df['duracion']
plt.scatter(range(len(column_data)), column_data, s=10, color='blue')
plt.xlabel('Índice datos')
plt.ylabel('Valor')
plt.title('Gráfica de duracion')
mask = column_data < 0.8
plt.scatter(np.where(mask)[0], column_data[mask], s=10, color='red')
plt.show()

# %%
# from pydub import AudioSegment
# from pydub.playback import play
# import pygame
# import time

# lista = duracion_df['RutaArchivo'].tolist()

# pygame.init()
# pygame.mixer.init()

# for audio_path in lista:
#     # Cargar el archivo de audio
#     audio = AudioSegment.from_file(audio_path)

#     # Reproducir el audio
#     pygame.mixer.music.load(audio_path)
#     pygame.mixer.music.play()

#     # Mostrar el nombre del archivo que se está reproduciendo
#     print("Reproduciendo:", audio_path)

#     # Pausar la reproducción durante 5 segundos
#     time.sleep(5)
#     pygame.mixer.music.pause()

#     # Esperar 2 segundos
#     time.sleep(2)

#     # Reanudar la reproducción
#     pygame.mixer.music.unpause()

#     # Esperar 5 segundos antes de reproducir el siguiente archivo
#     time.sleep(5)

# # Detener la reproducción al finalizar
# pygame.mixer.music.stop()
# pygame.quit()

# %%
pot_df = df_fallas[df_fallas['Promedio level pot'] <-53].copy()
conteosp = pot_df['Filtro'].value_counts()
print(conteosp)
pot_df
# Out:
# 0    17
# Name: Filtro, dtype: int64
#                                             RutaArchivo Nombre archivo  \
# 83    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001055020.wav
# 137   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001819890.wav
# 157   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002051680.wav
# 199   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002525560.wav
# 260   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003210880.wav
# 289   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003423394.wav
# 449   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005207737.wav
# 452   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005231565.wav
# 542   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010431760.wav
# 543   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010438843.wav
# 556   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010620475.wav
# 599   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011304200.wav
# 918   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003636440.wav
# 1074  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011535834.wav
# 1077  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011547000.wav
# 1079  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011602240.wav
# 1127  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013432750.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 83       1.296          -55.744952  -37.034980                  29.022741
# 137      1.680          -57.093929  -35.581069                  26.796238
# 157      2.088          -59.622737  -40.151881                  29.897259
# 199      2.904          -54.239232  -39.182949                  35.879615
# 260      4.488          -53.806015  -34.104348                  35.501692
# 289      1.416          -69.602472  -51.720620                  30.681382
# 449      0.960          -58.684443  -41.334872                  28.600692
# 452      4.344          -57.614132  -46.615170                  42.163663
# 542      2.016          -53.959689  -36.005652                  32.976376
# 543      2.424          -53.179605  -44.918740                  41.959832
# 556      1.248          -56.663236  -43.500116                  34.073255
# 599      1.800          -62.422320  -42.525677                  30.883114
# 918      3.120          -57.321481  -38.095795                  33.642107
# 1074     2.928          -59.472442  -44.642974                  37.918989
# 1077     3.744          -59.631316  -34.280924                  26.422296
# 1079     1.560          -59.549141  -38.782172                  27.239188
# 1127     0.888          -55.971891  -47.448703                  37.675841
#
#       Relación señal a ruido  Filtro  Falla en
# 83                 -3.183921       0         2
# 137                -3.874507       0         3
# 157                -3.883144       0         2
# 199                -3.943654       0         2
# 260                -3.934158       0         1
# 289                -3.880218       0         2
# 449                -3.796437       0         3
# 452                -1.713889       0         3
# 542                -3.926201       0         2
# 543                -3.865861       0         2
# 556                -3.547911       0         2
# 599                -3.955577       0         2
# 918                -3.903906       0         2
# 1074               -2.829903       0         3
# 1077               -1.653304       0         3
# 1079               -3.168474       0         3
# 1127               -2.531872       0         3

# %%
pot_df.describe()
# Out:
#         duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# count  17.000000           17.000000   17.000000                  17.000000
# mean    2.288471          -57.916414  -40.936861                  33.019664
# std     1.131599            3.937760    5.033624                   4.975041
# min     0.888000          -69.602472  -51.720620                  26.422296
# 25%     1.416000          -59.549141  -44.642974                  29.022741
# 50%     2.016000          -57.321481  -40.151881                  32.976376
# 75%     2.928000          -55.744952  -37.034980                  35.879615
# max     4.488000          -53.179605  -34.104348                  42.163663
#
#        Relación señal a ruido  Filtro   Falla en
# count               17.000000    17.0  17.000000
# mean                -3.387820     0.0   2.352941
# std                  0.773626     0.0   0.606339
# min                 -3.955577     0.0   1.000000
# 25%                 -3.903906     0.0   2.000000
# 50%                 -3.865861     0.0   2.000000
# 75%                 -3.168474     0.0   3.000000
# max                 -1.653304     0.0   3.000000

# %%
# lista = pot_df['RutaArchivo'].tolist()

# pygame.init()
# pygame.mixer.init()

# for audio_path in lista:
#     # Cargar el archivo de audio
#     audio = AudioSegment.from_file(audio_path)

#     # Reproducir el audio
#     pygame.mixer.music.load(audio_path)
#     pygame.mixer.music.play()

#     # Mostrar el nombre del archivo que se está reproduciendo
#     print("Reproduciendo:", audio_path)

#     # Pausar la reproducción durante 5 segundos
#  #   time.sleep(5)
#   #  pygame.mixer.music.pause()

#     # Esperar 2 segundos
#     time.sleep(2)

#     # Reanudar la reproducción
#     pygame.mixer.music.unpause()

#     # Esperar 5 segundos antes de reproducir el siguiente archivo
#     time.sleep(1)

# # Detener la reproducción al finalizar
# pygame.mixer.music.stop()
# pygame.quit()

# %%
column_data = df['Promedio level pot']
plt.scatter(range(len(column_data)), column_data, s=10, color='blue')
plt.xlabel('Índice datos')
plt.ylabel('Valor')
plt.title('Gráfica de Promedio nivel potencia')
mask = column_data <-53
plt.scatter(np.where(mask)[0], column_data[mask], s=10, color='red')
plt.show()

# %%
peak_df = df_fallas[df_fallas['Nivel peak'] <-35].copy()
conteospp = peak_df['Filtro'].value_counts()
print(conteospp)
peak_df
# Out:
# 0    27
# Name: Filtro, dtype: int64
#                                             RutaArchivo Nombre archivo  \
# 37    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000456960.wav
# 83    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001055020.wav
# 137   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001819890.wav
# 157   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002051680.wav
# 199   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002525560.wav
# 254   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003140160.wav
# 289   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003423394.wav
# 449   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005207737.wav
# 452   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005231565.wav
# 458   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005250600.wav
# 471   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005540120.wav
# 542   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010431760.wav
# 543   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010438843.wav
# 547   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010516320.wav
# 556   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010620475.wav
# 599   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011304200.wav
# 618   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011549760.wav
# 622   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011613697.wav
# 656   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012028960.wav
# 831   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001201800.wav
# 918   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003636440.wav
# 955   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004524480.wav
# 962   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004606320.wav
# 1074  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011535834.wav
# 1079  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011602240.wav
# 1127  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013432750.wav
# 1148  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  014735000.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 37       3.000          -48.896972  -35.070442                  37.692030
# 83       1.296          -55.744952  -37.034980                  29.022741
# 137      1.680          -57.093929  -35.581069                  26.796238
# 157      2.088          -59.622737  -40.151881                  29.897259
# 199      2.904          -54.239232  -39.182949                  35.879615
# 254      3.216          -49.695643  -35.345238                  37.236692
# 289      1.416          -69.602472  -51.720620                  30.681382
# 449      0.960          -58.684443  -41.334872                  28.600692
# 452      4.344          -57.614132  -46.615170                  42.163663
# 458      2.496          -47.820869  -37.519269                  40.029068
# 471      1.416          -52.078980  -40.509829                  38.662911
# 542      2.016          -53.959689  -36.005652                  32.976376
# 543      2.424          -53.179605  -44.918740                  41.959832
# 547      1.776          -51.849043  -37.599324                  34.527481
# 556      1.248          -56.663236  -43.500116                  34.073255
# 599      1.800          -62.422320  -42.525677                  30.883114
# 618      1.296          -46.592051  -36.540602                  38.680565
# 622      1.608          -49.236670  -38.159898                  38.084488
# 656      1.920          -52.935224  -35.629013                  31.749477
# 831      1.128          -50.991110  -41.061039                  36.914392
# 918      3.120          -57.321481  -38.095795                  33.642107
# 955      0.624          -47.083112  -37.906278                  36.664026
# 962      1.680          -48.136034  -35.085482                  36.185906
# 1074     2.928          -59.472442  -44.642974                  37.918989
# 1079     1.560          -59.549141  -38.782172                  27.239188
# 1127     0.888          -55.971891  -47.448703                  37.675841
# 1148     0.480          -45.232372  -37.906278                  36.026738
#
#       Relación señal a ruido  Filtro  Falla en
# 37                 -3.460862       0         1
# 83                 -3.183921       0         2
# 137                -3.874507       0         3
# 157                -3.883144       0         2
# 199                -3.943654       0         2
# 254                -3.938195       0         1
# 289                -3.880218       0         2
# 449                -3.796437       0         3
# 452                -1.713889       0         3
# 458                -2.016494       0         2
# 471                -1.505327       0         2
# 542                -3.926201       0         2
# 543                -3.865861       0         2
# 547                -3.307572       0         1
# 556                -3.547911       0         2
# 599                -3.955577       0         2
# 618                -3.896866       0         1
# 622                -3.453919       0         1
# 656                -3.971741       0         1
# 831                -2.189950       0         2
# 918                -3.903906       0         2
# 955                -2.739580       0         3
# 962                -3.561600       0         1
# 1074               -2.829903       0         3
# 1079               -3.168474       0         3
# 1127               -2.531872       0         3
# 1148               -3.475304       0         2

# %%
peak_df.describe()
# Out:
#         duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# count  27.000000           27.000000   27.000000                  27.000000
# mean    1.900444          -54.136659  -39.847187                  34.883854
# std     0.903876            5.597096    4.291633                   4.306505
# min     0.480000          -69.602472  -51.720620                  26.796238
# 25%     1.296000          -57.467807  -41.930275                  31.316296
# 50%     1.680000          -53.959689  -38.159898                  36.026738
# 75%     2.460000          -49.466157  -36.787791                  37.805509
# max     4.344000          -45.232372  -35.070442                  42.163663
#
#        Relación señal a ruido  Filtro   Falla en
# count               27.000000    27.0  27.000000
# mean                -3.315662     0.0   2.000000
# std                  0.743298     0.0   0.733799
# min                 -3.971741     0.0   1.000000
# 25%                 -3.890005     0.0   1.500000
# 50%                 -3.547911     0.0   2.000000
# 75%                 -2.999189     0.0   2.500000
# max                 -1.505327     0.0   3.000000

# %%
# lista = peak_df['RutaArchivo'].tolist()

# pygame.init()
# pygame.mixer.init()

# for audio_path in lista:
#     # Cargar el archivo de audio
#     audio = AudioSegment.from_file(audio_path)

#     # Reproducir el audio
#     pygame.mixer.music.load(audio_path)
#     pygame.mixer.music.play()

#     # Mostrar el nombre del archivo que se está reproduciendo
#     print("Reproduciendo:", audio_path)

#     # Pausar la reproducción durante 5 segundos
#  #   time.sleep(5)
#   #  pygame.mixer.music.pause()

#     # Esperar 2 segundos
#     time.sleep(2)

#     # Reanudar la reproducción
#     pygame.mixer.music.unpause()

#     # Esperar 5 segundos antes de reproducir el siguiente archivo
#     time.sleep(1)

# # Detener la reproducción al finalizar
# pygame.mixer.music.stop()
# pygame.quit()

# %%
column_data = df['Nivel peak']
plt.scatter(range(len(column_data)), column_data, s=10, color='blue')
plt.xlabel('Índice datos')
plt.ylabel('Valor')
plt.title('Gráfica de nivel peak')
mask = column_data <-35
plt.scatter(np.where(mask)[0], column_data[mask], s=10, color='red')
plt.show()

# %%
dis_df = df_fallas[df_fallas['Distorsión armónica total'] <29].copy()
conteosppd = dis_df['Filtro'].value_counts()
print(conteosppd)
dis_df
# Out:
# 0    30
# Name: Filtro, dtype: int64
#                                             RutaArchivo Nombre archivo  \
# 49    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000552400.wav
# 60    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000707320.wav
# 91    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001229360.wav
# 137   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001819890.wav
# 276   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003322120.wav
# 318   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003732200.wav
# 331   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003858520.wav
# 373   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004411160.wav
# 418   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004720600.wav
# 449   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005207737.wav
# 474   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005558720.wav
# 539   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010404607.wav
# 568   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010730723.wav
# 709   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012948087.wav
# 713   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013152487.wav
# 759   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015143720.wav
# 764   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015441400.wav
# 782   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000322600.wav
# 796   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000459400.wav
# 813   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000803520.wav
# 822   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001012520.wav
# 833   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001247040.wav
# 884   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002730640.wav
# 982   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005112360.wav
# 985   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005153760.wav
# 1018  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010010080.wav
# 1060  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011306940.wav
# 1077  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011547000.wav
# 1079  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011602240.wav
# 1135  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013818854.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 49       1.560          -41.701468  -21.672078                  28.007441
# 60       1.968          -44.540943  -24.010598                  28.535108
# 91       1.728          -43.591433  -24.040091                  28.964426
# 137      1.680          -57.093929  -35.581069                  26.796238
# 276      2.568          -34.727210  -13.325526                  28.829931
# 318      1.464          -45.102244  -25.508003                  28.173074
# 331      1.896          -42.510454  -22.486766                  28.892499
# 373      1.488          -40.720142  -17.585261                  24.534946
# 418      1.608          -41.628824  -22.395483                  28.970044
# 449      0.960          -58.684443  -41.334872                  28.600692
# 474      1.680          -37.030341  -11.152066                  24.005381
# 539      1.128          -42.388086  -24.652027                  28.926045
# 568      4.680          -46.660483  -21.867055                  28.014901
# 709      1.896          -44.707409  -24.297089                  28.491652
# 713      1.296          -40.275657  -21.601669                  28.578779
# 759      1.776          -45.079322  -23.246068                  26.713514
# 764      2.328          -41.021642  -19.980936                  28.762423
# 782      1.920          -40.090403  -15.943949                  24.635969
# 796      1.656          -33.936102  -14.493447                  28.885505
# 813      1.224          -38.831161  -20.478963                  28.655160
# 822      1.176          -41.305995  -22.991754                  28.514219
# 833      1.224          -38.521029  -20.315257                  28.806944
# 884      1.104          -37.773095  -17.731007                  26.427192
# 982      1.728          -49.912513  -27.251007                  25.719989
# 985      1.224          -41.692205  -23.595830                  28.920284
# 1018     1.176          -43.834312  -24.858243                  27.826549
# 1060     1.560          -39.132149  -18.944964                  27.843310
# 1077     3.744          -59.631316  -34.280924                  26.422296
# 1079     1.560          -59.549141  -38.782172                  27.239188
# 1135     2.088          -44.100430  -21.294781                  26.431392
#
#       Relación señal a ruido  Filtro  Falla en
# 49                 -3.942429       0         1
# 60                 -3.936065       0         1
# 91                 -3.943683       0         1
# 137                -3.874507       0         3
# 276                -3.938836       0         1
# 318                -3.941647       0         1
# 331                -3.942385       0         1
# 373                -3.937879       0         1
# 418                -3.922156       0         1
# 449                -3.796437       0         3
# 474                -3.926330       0         1
# 539                -3.942845       0         1
# 568                -3.877523       0         1
# 709                -3.944273       0         1
# 713                -3.927521       0         1
# 759                -3.940855       0         1
# 764                -3.944397       0         1
# 782                -3.902675       0         1
# 796                -3.925971       0         1
# 813                -3.933570       0         1
# 822                -3.941077       0         1
# 833                -3.880695       0         1
# 884                -3.943255       0         1
# 982                -3.671306       0         1
# 985                -3.883757       0         1
# 1018               -3.934729       0         1
# 1060               -3.944610       0         1
# 1077               -1.653304       0         3
# 1079               -3.168474       0         3
# 1135               -3.936422       0         1

# %%
dis_df.describe()
# Out:
#         duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# count  30.000000           30.000000   30.000000                  30.000000
# mean    1.769600          -43.859129  -23.189965                  27.670836
# std     0.770322            6.823274    6.861460                   1.455246
# min     0.960000          -59.631316  -41.334872                  24.005381
# 25%     1.242000          -44.986344  -24.563292                  26.734195
# 50%     1.632000          -42.044777  -22.441125                  28.332363
# 75%     1.896000          -40.136717  -20.064516                  28.795814
# max     4.680000          -33.936102  -11.152066                  28.970044
#
#        Relación señal a ruido  Filtro   Falla en
# count               30.000000    30.0  30.000000
# mean                -3.813320     0.0   1.266667
# std                  0.433627     0.0   0.691492
# min                 -3.944610     0.0   1.000000
# 25%                 -3.942200     0.0   1.000000
# 50%                 -3.935397     0.0   1.000000
# 75%                 -3.888486     0.0   1.000000
# max                 -1.653304     0.0   3.000000

# %%
lista = dis_df['RutaArchivo'].tolist()

pygame.init()
pygame.mixer.init()

for audio_path in lista:
    audio = AudioSegment.from_file(audio_path)
    pygame.mixer.music.load(audio_path)
    pygame.mixer.music.play()
    print("Reproduciendo:", audio_path)
 #   time.sleep(5)
  #  pygame.mixer.music.pause()
    time.sleep(2)
    # Reanudar la reproducción
    pygame.mixer.music.unpause()
    # Esperar 4 segundos antes de reproducir el siguiente archivo
    time.sleep(1)

# Detener la reproducción al finalizar
pygame.mixer.music.stop()
pygame.quit()
# Out:
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\000552400.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\000707320.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\001229360.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\001819890.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\003322120.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\003732200.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\003858520.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\004411160.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\004720600.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\005207737.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\005558720.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\010404607.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\010730723.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\012948087.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\013152487.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\015143720.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Train\015441400.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\000322600.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\000459400.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\000803520.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\001012520.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\001247040.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\002730640.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\005112360.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\005153760.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\010010080.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\011306940.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\011547000.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\011602240.wav
# Reproduciendo: D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW\Val\013818854.wav

# %%
column_data = df['Distorsión armónica total']
plt.scatter(range(len(column_data)), column_data, s=10, color='blue')
plt.xlabel('Índice datos')
plt.ylabel('Valor')
plt.title('Gráfica de Distorsión armónica total')
mask = column_data <29
plt.scatter(np.where(mask)[0], column_data[mask], s=10, color='red')
plt.show()

# %%
rsr_df = df_fallas[df_fallas['Relación señal a ruido'] > -3].copy()
conteosppde = rsr_df['Filtro'].value_counts()
print(conteosppde)
rsr_df
# Out:
# 0    43
# Name: Filtro, dtype: int64
#                                             RutaArchivo Nombre archivo  \
# 9     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000207560.wav
# 10    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000217360.wav
# 18    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000317144.wav
# 66    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000749320.wav
# 67    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000800760.wav
# 68    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000804120.wav
# 134   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001809774.wav
# 152   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002010400.wav
# 153   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002014840.wav
# 156   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002021400.wav
# 177   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002302057.wav
# 189   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002443480.wav
# 237   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002941400.wav
# 271   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003314854.wav
# 297   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003556960.wav
# 303   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003639560.wav
# 310   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003714360.wav
# 328   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003849000.wav
# 377   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004424374.wav
# 379   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004432000.wav
# 381   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004441414.wav
# 413   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004653400.wav
# 426   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004853480.wav
# 452   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005231565.wav
# 458   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005250600.wav
# 471   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005540120.wav
# 492   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005924440.wav
# 498   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005948120.wav
# 574   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010845040.wav
# 690   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012554740.wav
# 696   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012724800.wav
# 701   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012801400.wav
# 705   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012910320.wav
# 831   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001201800.wav
# 940   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004056050.wav
# 955   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004524480.wav
# 1061  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011309840.wav
# 1065  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011341440.wav
# 1074  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011535834.wav
# 1076  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011543240.wav
# 1077  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011547000.wav
# 1101  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012433520.wav
# 1127  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013432750.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 9        1.728          -39.223048  -28.653291                  40.175655
# 10       1.536          -40.293798  -24.970260                  32.787709
# 18       3.744          -42.290238  -24.069685                  37.319321
# 66       2.496          -35.730742  -27.467469                  42.270446
# 67       2.040          -33.146260  -21.560330                  38.814016
# 68       1.536          -35.114041  -25.891154                  39.426796
# 134      1.488          -31.598080  -18.456582                  35.534389
# 152      2.256          -31.467705  -18.269971                  36.653257
# 153      3.408          -32.710981  -19.598053                  38.554474
# 156      1.896          -26.289600  -13.618042                  36.421011
# 177      1.248          -39.481240  -28.864001                  36.662686
# 189      1.296          -35.269511  -22.961880                  39.578017
# 237      1.488          -31.098454  -19.943986                  37.005529
# 271      2.520          -33.776259  -24.802772                  41.566083
# 297      1.104          -41.875160  -29.959984                  36.780574
# 303      2.256          -33.001202  -21.031139                  37.897742
# 310      4.008          -33.381770  -18.032162                  37.002259
# 328      1.104          -38.857702  -27.530320                  35.419753
# 377      1.296          -33.394086  -21.608046                  35.642069
# 379      1.464          -39.215397  -24.446169                  34.245595
# 381      2.088          -29.797057  -19.540038                  40.138283
# 413      2.040          -33.228732  -20.063317                  36.242421
# 426      2.136          -33.933828  -23.429017                  40.912968
# 452      4.344          -57.614132  -46.615170                  42.163663
# 458      2.496          -47.820869  -37.519269                  40.029068
# 471      1.416          -52.078980  -40.509829                  38.662911
# 492      1.104          -32.138814  -19.524967                  34.090443
# 498      2.280          -38.095720  -20.933193                  32.661341
# 574      2.664          -36.773465  -21.550818                  35.681323
# 690      1.224          -31.622529  -18.752272                  34.285895
# 696      1.416          -32.325664  -21.316346                  36.821312
# 701      2.208          -25.100784  -13.943161                  38.625604
# 705      1.680          -23.803704  -12.805458                  37.585287
# 831      1.128          -50.991110  -41.061039                  36.914392
# 940      2.184          -23.491327  -13.009289                  39.260838
# 955      0.624          -47.083112  -37.906278                  36.664026
# 1061     1.296          -39.425860  -23.342901                  33.394022
# 1065     0.960          -43.811544  -29.209081                  31.434854
# 1074     2.928          -59.472442  -44.642974                  37.918989
# 1076     2.040          -31.436319  -19.648818                  39.867255
# 1077     3.744          -59.631316  -34.280924                  26.422296
# 1101     1.560          -26.646716  -16.619273                  38.242496
# 1127     0.888          -55.971891  -47.448703                  37.675841
#
#       Relación señal a ruido  Filtro  Falla en
# 9                  -2.535412       0         1
# 10                 -2.785249       0         1
# 18                 -2.893962       0         1
# 66                 -2.664026       0         1
# 67                 -2.688730       0         1
# 68                 -2.741007       0         1
# 134                -2.407258       0         1
# 152                -2.970862       0         1
# 153                -2.707497       0         1
# 156                -2.390812       0         1
# 177                -2.962579       0         1
# 189                -2.549636       0         1
# 237                -2.269533       0         1
# 271                -2.708589       0         1
# 297                -1.216967       0         1
# 303                -2.689853       0         1
# 310                -2.625554       0         1
# 328                -2.590494       0         1
# 377                -2.666973       0         1
# 379                -0.146588       0         1
# 381                -2.181025       0         1
# 413                -2.979640       0         1
# 426                -2.234691       0         1
# 452                -1.713889       0         3
# 458                -2.016494       0         2
# 471                -1.505327       0         2
# 492                -2.233107       0         1
# 498                -2.663071       0         1
# 574                -2.966366       0         1
# 690                -2.674576       0         1
# 696                -2.916844       0         1
# 701                -2.574717       0         1
# 705                -2.949225       0         1
# 831                -2.189950       0         2
# 940                -2.808448       0         1
# 955                -2.739580       0         3
# 1061               -2.514339       0         1
# 1065               -2.317796       0         1
# 1074               -2.829903       0         3
# 1076               -2.963812       0         1
# 1077               -1.653304       0         3
# 1101               -2.455969       0         1
# 1127               -2.531872       0         3

# %%
rsr_df.describe()
# Out:
#         duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# count  43.000000           43.000000   43.000000                  43.000000
# mean    1.961860          -37.663051  -25.242033                  37.103556
# std     0.876295            9.322426    8.991726                   3.030586
# min     0.624000          -59.631316  -47.448703                  26.422296
# 25%     1.296000          -41.084479  -28.758646                  35.661696
# 50%     1.728000          -35.114041  -22.961880                  37.005529
# 75%     2.268000          -31.880671  -19.569045                  39.037427
# max     4.344000          -23.491327  -12.805458                  42.270446
#
#        Relación señal a ruido  Filtro   Falla en
# count               43.000000    43.0  43.000000
# mean                -2.461059     0.0   1.302326
# std                  0.544678     0.0   0.673826
# min                 -2.979640     0.0   1.000000
# 25%                 -2.763128     0.0   1.000000
# 50%                 -2.625554     0.0   1.000000
# 75%                 -2.293665     0.0   1.000000
# max                 -0.146588     0.0   3.000000

# %%
# lista = rsr_df['RutaArchivo'].tolist()

# pygame.init()
# pygame.mixer.init()

# for audio_path in lista:
#     # Cargar el archivo de audio
#     audio = AudioSegment.from_file(audio_path)

#     # Reproducir el audio
#     pygame.mixer.music.load(audio_path)
#     pygame.mixer.music.play()

#     # Mostrar el nombre del archivo que se está reproduciendo
#     print("Reproduciendo:", audio_path)

#     # Pausar la reproducción durante 5 segundos
#  #   time.sleep(5)
#   #  pygame.mixer.music.pause()

#     # Esperar 2 segundos
#     time.sleep(2)

#     # Reanudar la reproducción
#     pygame.mixer.music.unpause()

#     # Esperar 5 segundos antes de reproducir el siguiente archivo
#     time.sleep(1)

# # Detener la reproducción al finalizar
# pygame.mixer.music.stop()

# %%
column_data = df['Relación señal a ruido']
plt.scatter(range(len(column_data)), column_data, s=10, color='blue')
plt.xlabel('Índice datos')
plt.ylabel('Valor')
plt.title('Gráfica de Relación señal a ruido')
mask = column_data > -3
plt.scatter(np.where(mask)[0], column_data[mask], s=10, color='red')
plt.show()

# %%
# lista = df_fallas['RutaArchivo'].tolist()

# pygame.init()
# pygame.mixer.init()

# for audio_path in lista:
#     # Cargar el archivo de audio
#     audio = AudioSegment.from_file(audio_path)

#     # Reproducir el audio
#     pygame.mixer.music.load(audio_path)
#     pygame.mixer.music.play()

#     # Mostrar el nombre del archivo que se está reproduciendo
#     print("Reproduciendo:", audio_path)

#     # Pausar la reproducción durante 5 segundos
#     #time.sleep(5)
#     #pygame.mixer.music.pause()

#     # Esperar 2 segundos
#     time.sleep(2)

#     # Reanudar la reproducción
#     pygame.mixer.music.unpause()

#     # Esperar 5 segundos antes de reproducir el siguiente archivo
#     time.sleep(1)

# # Detener la reproducción al finalizar
# pygame.mixer.music.stop()
# pygame.quit()

# %%
df_fallas
# Out:
#                                             RutaArchivo Nombre archivo  \
# 9     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000207560.wav
# 10    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000217360.wav
# 18    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000317144.wav
# 37    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000456960.wav
# 49    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000552400.wav
# ...                                                 ...            ...
# 1079  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011602240.wav
# 1101  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012433520.wav
# 1127  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013432750.wav
# 1135  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013818854.wav
# 1148  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  014735000.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 9        1.728          -39.223048  -28.653291                  40.175655
# 10       1.536          -40.293798  -24.970260                  32.787709
# 18       3.744          -42.290238  -24.069685                  37.319321
# 37       3.000          -48.896972  -35.070442                  37.692030
# 49       1.560          -41.701468  -21.672078                  28.007441
# ...        ...                 ...         ...                        ...
# 1079     1.560          -59.549141  -38.782172                  27.239188
# 1101     1.560          -26.646716  -16.619273                  38.242496
# 1127     0.888          -55.971891  -47.448703                  37.675841
# 1135     2.088          -44.100430  -21.294781                  26.431392
# 1148     0.480          -45.232372  -37.906278                  36.026738
#
#       Relación señal a ruido  Filtro  Falla en
# 9                  -2.535412       0         1
# 10                 -2.785249       0         1
# 18                 -2.893962       0         1
# 37                 -3.460862       0         1
# 49                 -3.942429       0         1
# ...                      ...     ...       ...
# 1079               -3.168474       0         3
# 1101               -2.455969       0         1
# 1127               -2.531872       0         3
# 1135               -3.936422       0         1
# 1148               -3.475304       0         2
#
# [104 rows x 9 columns]

# %%
df_buenas
# Out:
#                                             RutaArchivo Nombre archivo  \
# 0     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000029301.wav
# 1     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000046280.wav
# 2     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000059880.wav
# 3     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000102534.wav
# 4     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000141494.wav
# ...                                                 ...            ...
# 1151  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015145521.wav
# 1152  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015238600.wav
# 1153  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015626280.wav
# 1154  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015646720.wav
# 1155  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  021837840.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0        2.448          -26.925982  -13.179254                  36.456134
# 1        3.888          -32.735003  -18.008946                  38.684294
# 2        1.920          -35.309039  -21.557158                  35.378896
# 3        2.496          -33.410550  -19.041751                  36.274271
# 4        3.048          -32.634227  -21.347245                  40.629692
# ...        ...                 ...         ...                        ...
# 1151     4.056          -35.648422  -20.992422                  41.414802
# 1152     2.928          -47.447955  -25.659241                  29.019201
# 1153     3.096          -38.485362  -22.614764                  35.334409
# 1154     2.040          -37.083908  -22.043003                  35.543562
# 1155     3.096          -32.157792  -18.205053                  37.281666
#
#       Relación señal a ruido  Filtro  Falla en
# 0                  -3.733383       1         0
# 1                  -3.522599       1         0
# 2                  -3.944569       1         0
# 3                  -3.878937       1         0
# 4                  -3.941288       1         0
# ...                      ...     ...       ...
# 1151               -3.855075       1         0
# 1152               -3.944673       1         0
# 1153               -3.944595       1         0
# 1154               -3.944599       1         0
# 1155               -3.942387       1         0
#
# [1052 rows x 9 columns]

# %%
column_data = df['Filtro']
plt.scatter(range(len(column_data)), column_data, s=10, color='red')
plt.xlabel('Índice datos')
plt.ylabel('Valor')
plt.title('Gráfica de Filtro')
mask = column_data > 0
plt.scatter(np.where(mask)[0], column_data[mask], s=10, color='green')
plt.show()

# %%
df_fallas.describe()
# Out:
#          duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# count  104.000000          104.000000  104.000000                 104.000000
# mean     1.740692          -41.439374  -26.350100                  33.476851
# std      0.886938            9.948496    9.262137                   4.688375
# min      0.408000          -69.602472  -51.720620                  24.005381
# 25%      1.176000          -48.267628  -35.074202                  28.913337
# 50%      1.560000          -40.183030  -23.294485                  34.081849
# 75%      2.088000          -33.391007  -19.971698                  37.063320
# max      4.680000          -23.491327  -11.152066                  42.270446
#
#        Relación señal a ruido  Filtro    Falla en
# count              104.000000   104.0  104.000000
# mean                -3.250985     0.0    1.278846
# std                  0.769308     0.0    0.598651
# min                 -4.011207     0.0    1.000000
# 25%                 -3.926233     0.0    1.000000
# 50%                 -3.513075     0.0    1.000000
# 75%                 -2.685191     0.0    1.000000
# max                 -0.146588     0.0    3.000000

# %%
condicion = (df_fallas['Falla en'] <= 1) & (df_fallas['Relación señal a ruido'] <= -3)
df_fallas['Filtro2'] = condicion.astype(int)
df_fallas.loc[condicion, 'Filtro2'] = 1
df_fallas
# Out:
#                                             RutaArchivo Nombre archivo  \
# 9     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000207560.wav
# 10    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000217360.wav
# 18    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000317144.wav
# 37    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000456960.wav
# 49    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000552400.wav
# ...                                                 ...            ...
# 1079  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011602240.wav
# 1101  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012433520.wav
# 1127  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013432750.wav
# 1135  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013818854.wav
# 1148  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  014735000.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 9        1.728          -39.223048  -28.653291                  40.175655
# 10       1.536          -40.293798  -24.970260                  32.787709
# 18       3.744          -42.290238  -24.069685                  37.319321
# 37       3.000          -48.896972  -35.070442                  37.692030
# 49       1.560          -41.701468  -21.672078                  28.007441
# ...        ...                 ...         ...                        ...
# 1079     1.560          -59.549141  -38.782172                  27.239188
# 1101     1.560          -26.646716  -16.619273                  38.242496
# 1127     0.888          -55.971891  -47.448703                  37.675841
# 1135     2.088          -44.100430  -21.294781                  26.431392
# 1148     0.480          -45.232372  -37.906278                  36.026738
#
#       Relación señal a ruido  Filtro  Falla en  Filtro2
# 9                  -2.535412       0         1        0
# 10                 -2.785249       0         1        0
# 18                 -2.893962       0         1        0
# 37                 -3.460862       0         1        1
# 49                 -3.942429       0         1        1
# ...                      ...     ...       ...      ...
# 1079               -3.168474       0         3        0
# 1101               -2.455969       0         1        0
# 1127               -2.531872       0         3        0
# 1135               -3.936422       0         1        1
# 1148               -3.475304       0         2        0
#
# [104 rows x 10 columns]

# %%
contars = df_fallas['Filtro2'].value_counts()
print(contars)
# Out:
# 0    56
# 1    48
# Name: Filtro2, dtype: int64

# %%
df_fallas2 = df_fallas[df_fallas['Filtro2'] == 0].copy()
df_buenas2 = df_fallas[df_fallas['Filtro2'] == 1].copy()

# %%
df_buenas2
# Out:
#                                             RutaArchivo Nombre archivo  \
# 37    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000456960.wav
# 49    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000552400.wav
# 60    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000707320.wav
# 85    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001113440.wav
# 91    D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001229360.wav
# 138   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001821420.wav
# 194   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002516934.wav
# 254   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003140160.wav
# 260   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003210880.wav
# 273   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003316894.wav
# 276   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003322120.wav
# 318   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003732200.wav
# 331   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  003858520.wav
# 373   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004411160.wav
# 418   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004720600.wav
# 428   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004924334.wav
# 474   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005558720.wav
# 539   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010404607.wav
# 547   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010516320.wav
# 568   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010730723.wav
# 618   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011549760.wav
# 621   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011603980.wav
# 622   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011613697.wav
# 656   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012028960.wav
# 708   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012943150.wav
# 709   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  012948087.wav
# 713   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013152487.wav
# 754   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  014643120.wav
# 759   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015143720.wav
# 764   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015441400.wav
# 781   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000322047.wav
# 782   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000322600.wav
# 786   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000403327.wav
# 796   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000459400.wav
# 813   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000803520.wav
# 822   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001012520.wav
# 829   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001130680.wav
# 833   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001247040.wav
# 849   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  001703120.wav
# 884   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  002730640.wav
# 952   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004512014.wav
# 962   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  004606320.wav
# 982   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005112360.wav
# 985   D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  005153760.wav
# 1018  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010010080.wav
# 1031  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  010320007.wav
# 1060  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  011306940.wav
# 1135  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  013818854.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 37       3.000          -48.896972  -35.070442                  37.692030
# 49       1.560          -41.701468  -21.672078                  28.007441
# 60       1.968          -44.540943  -24.010598                  28.535108
# 85       0.768          -28.277904  -15.595424                  32.409875
# 91       1.728          -43.591433  -24.040091                  28.964426
# 138      0.528          -31.030312  -20.400887                  32.845620
# 194      0.744          -34.882149  -23.040520                  34.093665
# 254      3.216          -49.695643  -35.345238                  37.236692
# 260      4.488          -53.806015  -34.104348                  35.501692
# 273      0.696          -30.668156  -20.473363                  34.513765
# 276      2.568          -34.727210  -13.325526                  28.829931
# 318      1.464          -45.102244  -25.508003                  28.173074
# 331      1.896          -42.510454  -22.486766                  28.892499
# 373      1.488          -40.720142  -17.585261                  24.534946
# 418      1.608          -41.628824  -22.395483                  28.970044
# 428      0.768          -29.888349  -19.904570                  35.885761
# 474      1.680          -37.030341  -11.152066                  24.005381
# 539      1.128          -42.388086  -24.652027                  28.926045
# 547      1.776          -51.849043  -37.599324                  34.527481
# 568      4.680          -46.660483  -21.867055                  28.014901
# 618      1.296          -46.592051  -36.540602                  38.680565
# 621      0.408          -33.261932  -22.465616                  32.241188
# 622      1.608          -49.236670  -38.159898                  38.084488
# 656      1.920          -52.935224  -35.629013                  31.749477
# 708      0.624          -32.535602  -19.535011                  31.993382
# 709      1.896          -44.707409  -24.297089                  28.491652
# 713      1.296          -40.275657  -21.601669                  28.578779
# 754      0.768          -48.662410  -32.865873                  29.217677
# 759      1.776          -45.079322  -23.246068                  26.713514
# 764      2.328          -41.021642  -19.980936                  28.762423
# 781      0.696          -24.535419  -12.569038                  33.663542
# 782      1.920          -40.090403  -15.943949                  24.635969
# 786      0.624          -38.134963  -24.284057                  30.283557
# 796      1.656          -33.936102  -14.493447                  28.885505
# 813      1.224          -38.831161  -20.478963                  28.655160
# 822      1.176          -41.305995  -22.991754                  28.514219
# 829      0.696          -34.125034  -22.969339                  33.533733
# 833      1.224          -38.521029  -20.315257                  28.806944
# 849      0.768          -35.799578  -20.540805                  29.761421
# 884      1.104          -37.773095  -17.731007                  26.427192
# 952      0.768          -33.915620  -20.588895                  31.749591
# 962      1.680          -48.136034  -35.085482                  36.185906
# 982      1.728          -49.912513  -27.251007                  25.719989
# 985      1.224          -41.692205  -23.595830                  28.920284
# 1018     1.176          -43.834312  -24.858243                  27.826549
# 1031     0.696          -29.187971  -19.774461                  35.543299
# 1060     1.560          -39.132149  -18.944964                  27.843310
# 1135     2.088          -44.100430  -21.294781                  26.431392
#
#       Relación señal a ruido  Filtro  Falla en  Filtro2
# 37                 -3.460862       0         1        1
# 49                 -3.942429       0         1        1
# 60                 -3.936065       0         1        1
# 85                 -3.426222       0         1        1
# 91                 -3.943683       0         1        1
# 138                -4.011207       0         1        1
# 194                -3.887955       0         1        1
# 254                -3.938195       0         1        1
# 260                -3.934158       0         1        1
# 273                -3.300974       0         1        1
# 276                -3.938836       0         1        1
# 318                -3.941647       0         1        1
# 331                -3.942385       0         1        1
# 373                -3.937879       0         1        1
# 418                -3.922156       0         1        1
# 428                -3.897001       0         1        1
# 474                -3.926330       0         1        1
# 539                -3.942845       0         1        1
# 547                -3.307572       0         1        1
# 568                -3.877523       0         1        1
# 618                -3.896866       0         1        1
# 621                -3.818926       0         1        1
# 622                -3.453919       0         1        1
# 656                -3.971741       0         1        1
# 708                -3.478240       0         1        1
# 709                -3.944273       0         1        1
# 713                -3.927521       0         1        1
# 754                -3.896165       0         1        1
# 759                -3.940855       0         1        1
# 764                -3.944397       0         1        1
# 781                -3.723561       0         1        1
# 782                -3.902675       0         1        1
# 786                -3.942433       0         1        1
# 796                -3.925971       0         1        1
# 813                -3.933570       0         1        1
# 822                -3.941077       0         1        1
# 829                -3.788783       0         1        1
# 833                -3.880695       0         1        1
# 849                -3.892395       0         1        1
# 884                -3.943255       0         1        1
# 952                -3.822011       0         1        1
# 962                -3.561600       0         1        1
# 982                -3.671306       0         1        1
# 985                -3.883757       0         1        1
# 1018               -3.934729       0         1        1
# 1031               -3.554140       0         1        1
# 1060               -3.944610       0         1        1
# 1135               -3.936422       0         1        1

# %%
# lista = df_buenas2['RutaArchivo'].tolist()

# pygame.init()
# pygame.mixer.init()

# for audio_path in lista:
#     # Cargar el archivo de audio
#     audio = AudioSegment.from_file(audio_path)

#     # Reproducir el audio
#     pygame.mixer.music.load(audio_path)
#     pygame.mixer.music.play()

#     # Mostrar el nombre del archivo que se está reproduciendo
#     print("Reproduciendo:", audio_path)

#     # Pausar la reproducción durante 5 segundos
#     #time.sleep(5)
#     #pygame.mixer.music.pause()

#     # Esperar 2 segundos
#     time.sleep(2)

#     # Reanudar la reproducción
#     pygame.mixer.music.unpause()

#     # Esperar 5 segundos antes de reproducir el siguiente archivo
#     time.sleep(1)

# # Detener la reproducción al finalizar
# pygame.mixer.music.stop()
# pygame.quit()

# %%
condi = (df['Falla en'] <= 1) & (df['Relación señal a ruido'] <= -3)
df['Filtro2'] = condi.astype(int)
df.loc[condi, 'Filtro2'] = 1
df
# Out:
#                                             RutaArchivo Nombre archivo  \
# 0     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000029301.wav
# 1     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000046280.wav
# 2     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000059880.wav
# 3     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000102534.wav
# 4     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000141494.wav
# ...                                                 ...            ...
# 1151  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015145521.wav
# 1152  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015238600.wav
# 1153  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015626280.wav
# 1154  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015646720.wav
# 1155  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  021837840.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0        2.448          -26.925982  -13.179254                  36.456134
# 1        3.888          -32.735003  -18.008946                  38.684294
# 2        1.920          -35.309039  -21.557158                  35.378896
# 3        2.496          -33.410550  -19.041751                  36.274271
# 4        3.048          -32.634227  -21.347245                  40.629692
# ...        ...                 ...         ...                        ...
# 1151     4.056          -35.648422  -20.992422                  41.414802
# 1152     2.928          -47.447955  -25.659241                  29.019201
# 1153     3.096          -38.485362  -22.614764                  35.334409
# 1154     2.040          -37.083908  -22.043003                  35.543562
# 1155     3.096          -32.157792  -18.205053                  37.281666
#
#       Relación señal a ruido  Filtro  Falla en  Filtro2
# 0                  -3.733383       1         0        1
# 1                  -3.522599       1         0        1
# 2                  -3.944569       1         0        1
# 3                  -3.878937       1         0        1
# 4                  -3.941288       1         0        1
# ...                      ...     ...       ...      ...
# 1151               -3.855075       1         0        1
# 1152               -3.944673       1         0        1
# 1153               -3.944595       1         0        1
# 1154               -3.944599       1         0        1
# 1155               -3.942387       1         0        1
#
# [1156 rows x 10 columns]

# %%
contars2 = df['Filtro2'].value_counts()
print(contars2)
# Out:
# 1    1100
# 0      56
# Name: Filtro2, dtype: int64

# %%
df.to_csv(r"D:\sentirobots\Datasets\AFEW\Datos\Filtro de audios - AFEW\filtro-audio-AFEW.csv", index=False)
print("Se ha generado el archivo")
# Out:
# Se ha generado el archivo

# %% [markdown]
# ## Transcripción

# %%
import os
import pandas as pd
import librosa
from speechbrain.pretrained import EncoderDecoderASR
from tqdm import tqdm
import numpy as np
import torch
# Out:
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.

# %%
rutaa= r"D:\sentirobots\Datasets\AFEW\Datos\Filtro de audios - AFEW\filtro-audio-AFEW.csv"
df = pd.read_csv(rutaa)
df
# Out:
#                                             RutaArchivo Nombre archivo  \
# 0     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000029301.wav
# 1     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000046280.wav
# 2     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000059880.wav
# 3     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000102534.wav
# 4     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000141494.wav
# ...                                                 ...            ...
# 1151  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015145521.wav
# 1152  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015238600.wav
# 1153  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015626280.wav
# 1154  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015646720.wav
# 1155  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  021837840.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0        2.448          -26.925982  -13.179254                  36.456134
# 1        3.888          -32.735003  -18.008946                  38.684294
# 2        1.920          -35.309039  -21.557158                  35.378896
# 3        2.496          -33.410550  -19.041751                  36.274271
# 4        3.048          -32.634227  -21.347245                  40.629692
# ...        ...                 ...         ...                        ...
# 1151     4.056          -35.648422  -20.992422                  41.414802
# 1152     2.928          -47.447955  -25.659241                  29.019201
# 1153     3.096          -38.485362  -22.614764                  35.334409
# 1154     2.040          -37.083908  -22.043003                  35.543562
# 1155     3.096          -32.157792  -18.205053                  37.281666
#
#       Relación señal a ruido  Filtro  Falla en  Filtro2
# 0                  -3.733383       1         0        1
# 1                  -3.522599       1         0        1
# 2                  -3.944569       1         0        1
# 3                  -3.878937       1         0        1
# 4                  -3.941288       1         0        1
# ...                      ...     ...       ...      ...
# 1151               -3.855075       1         0        1
# 1152               -3.944673       1         0        1
# 1153               -3.944595       1         0        1
# 1154               -3.944599       1         0        1
# 1155               -3.942387       1         0        1
#
# [1156 rows x 10 columns]

# %% [markdown]
# ## SpeechBrain

# %%
# Carga el modelo de extracción de texto.
model = EncoderDecoderASR.from_hparams(
    source="speechbrain/asr-transformer-transformerlm-librispeech",
    savedir="pretrained_models/asr-transformer-transformerlm-librispeech",
#    run_opts={'device':'cuda'},
)
sample_rate = 22400
max_time = 7.
texts = []

# %%
df['Transcripcion'] = ''

for index, row in tqdm(df[df['Filtro2'] < 3].iterrows()):
    audiofile, _ = librosa.load(path=row['RutaArchivo'], sr=22400, duration=np.minimum(row['duracion'], 7.))
    if row['duracion'] < 7.:
        audiofile = librosa.util.pad_center(data=audiofile, size=22400*7)
    normalized = model.audio_normalizer(torch.tensor(audiofile), 22400)
    rel_length = torch.tensor([1.])
    predicted_words, _ = model.transcribe_batch(
        normalized.unsqueeze(0),
        rel_length,
    )
    normalized = normalized.detach()
    rel_length = rel_length.detach()
    torch.cuda.empty_cache()
    df.at[index, 'Transcripcion'] = " ".join(predicted_words)

    df
# Out:
# 0it [00:00, ?it/s]C:\Users\Desarrollo\AppData\Roaming\Python\Python38\site-packages\torch\functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\SpectralOps.cpp:867.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# C:\Users\Desarrollo\AppData\Roaming\Python\Python38\site-packages\torch\nn\functional.py:4999: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# 1156it [14:10:00, 44.12s/it]
#                                             RutaArchivo Nombre archivo  \
# 0     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000029301.wav
# 1     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000046280.wav
# 2     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000059880.wav
# 3     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000102534.wav
# 4     D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  000141494.wav
# ...                                                 ...            ...
# 1151  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015145521.wav
# 1152  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015238600.wav
# 1153  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015626280.wav
# 1154  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  015646720.wav
# 1155  D:\sentirobots\Datasets\AFEW\Datos\Audios_AFEW...  021837840.wav
#
#       duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0        2.448          -26.925982  -13.179254                  36.456134
# 1        3.888          -32.735003  -18.008946                  38.684294
# 2        1.920          -35.309039  -21.557158                  35.378896
# 3        2.496          -33.410550  -19.041751                  36.274271
# 4        3.048          -32.634227  -21.347245                  40.629692
# ...        ...                 ...         ...                        ...
# 1151     4.056          -35.648422  -20.992422                  41.414802
# 1152     2.928          -47.447955  -25.659241                  29.019201
# 1153     3.096          -38.485362  -22.614764                  35.334409
# 1154     2.040          -37.083908  -22.043003                  35.543562
# 1155     3.096          -32.157792  -18.205053                  37.281666
#
#       Relación señal a ruido  Filtro  Falla en  Filtro2  \
# 0                  -3.733383       1         0        1
# 1                  -3.522599       1         0        1
# 2                  -3.944569       1         0        1
# 3                  -3.878937       1         0        1
# 4                  -3.941288       1         0        1
# ...                      ...     ...       ...      ...
# 1151               -3.855075       1         0        1
# 1152               -3.944673       1         0        1
# 1153               -3.944595       1         0        1
# 1154               -3.944599       1         0        1
# 1155               -3.942387       1         0        1
#
#                                           Transcripcion
# 0                                                  IMMY
# 1                        BUT I SAY THIS TO OUR CITIZENS
# 2                             IT IS YOU KNOW WHAT IT IS
# 3                              ENSLAVEMENT OF A MAN MAY
# 4         JUST ABOUT EVERYTHING I KNOW ABOUT WOMEN LOVE
# ...                                                 ...
# 1151  HE'S GOOD WITH NUMBERS TOO AND HE WORKS FOR TH...
# 1152                            I CAN'T SEE THE MAKE UP
# 1153           BUT LEVIN HE THOUGHT YOU'RE TOO BROKE NO
# 1154                               I KNOW THAT YOU LOVE
# 1155  ALWAYS HAD THE SACRED RIGHT TO FLY THE IT LIES...
#
# [1156 rows x 11 columns]

# %%
columna = "Transcripcion"
num_vacios = df[columna].eq('').sum()
total_registros = df[columna].shape[0]
porcentaje_vacios = (num_vacios / total_registros) * 100

print("Número de valores vacíos en la columna {}: {}".format(columna, num_vacios))
print("Total de registros en la columna {}: {}".format(columna, total_registros))
print("Porcentaje de valores vacíos en la columna {}: {:.2f}%".format(columna, porcentaje_vacios))
# Out:
# Número de valores vacíos en la columna Transcripcion: 0
# Total de registros en la columna Transcripcion: 1156
# Porcentaje de valores vacíos en la columna Transcripcion: 0.00%

# %%
df.to_csv(r'D:\sentirobots\Datasets\Transcripcion-AFEW.csv', index=False)
print("Realizado")
# Out:
# Realizado
