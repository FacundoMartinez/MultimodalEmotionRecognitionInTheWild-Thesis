# %% [markdown]
# # TEXTO

# %%
import os
from glob import glob
import numpy as np
from tqdm import tqdm
import torch
from speechbrain.pretrained import EncoderDecoderASR
import librosa
import pandas as pd
# Out:
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.
# The torchaudio backend is switched to 'soundfile'. Note that 'sox_io' is not supported on Windows.

# %% [markdown]
# ## Construcción de Dataset
# Es identico al de audio, pero además se obtiene el texto, agregando este campo al csv.

# %%
model = EncoderDecoderASR.from_hparams(
    source="speechbrain/asr-transformer-transformerlm-librispeech",
    savedir="pretrained_models/asr-transformer-transformerlm-librispeech",
#    run_opts={'device':'cuda'},
)
sample_rate = 22400
max_time = 7.

texts = []

# %%
import os
import pandas as pd
import librosa

def obtener_nombres_archivos(ruta):
    archivos = []
    for nombre_archivo in os.listdir(ruta):
        if os.path.isfile(os.path.join(ruta, nombre_archivo)):
            ruta_completa = os.path.join(ruta, nombre_archivo)
            duracion = obtener_duracion_audio(ruta_completa)
            archivos.append({'NombreArchivo': nombre_archivo, 'RutaArchivo': ruta_completa, 'Duracion': duracion})
    df = pd.DataFrame(archivos)
    return df

def obtener_duracion_audio(ruta_archivo):
    audio, sr = librosa.load(ruta_archivo)
    duracion = len(audio) / sr
    return duracion

ruta_carpeta = r'D:\sentirobots\Datasets\MAFW\MAFW-20230614T154044Z-003\MAFW\data\Audibles'  # Reemplazar con la ruta de la carpeta deseada
df = obtener_nombres_archivos(ruta_carpeta)
df
# Out:
#      NombreArchivo                                        RutaArchivo  \
# 0        00019.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
# 1        00020.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
# 2        00021.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
# 3        00022.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
# 4        00024.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
# ...            ...                                                ...
# 9969     20094.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
# 9970     20095.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
# 9971     20096.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
# 9972     20097.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
# 9973     20098.wav  D:\sentirobots\Datasets\MAFW\MAFW-20230614T154...
#
#       Duracion
# 0         1.84
# 1         4.88
# 2         2.80
# 3         5.42
# 4         2.16
# ...        ...
# 9969      2.32
# 9970      2.36
# 9971      3.12
# 9972      1.16
# 9973      2.36
#
# [9974 rows x 3 columns]

# %% [markdown]
# # SpeechBrain

# %%
# traindf = pd.DataFrame(columns=['filename', 'Duration','Text'])
# for _, row in tqdm(df.iterrows()):
#     audiofile, _ = librosa.load(path=row['RutaArchivo'], sr=22400, duration=np.minimum(row['Duracion'], 7.))
    

#     if row['Duracion'] < 7.:
#         audiofile = librosa.util.pad_center(data=audiofile, size=22400*7)

#     normalized = model.audio_normalizer(torch.tensor(audiofile), 22400)
#     rel_length = torch.tensor([1.])
#     predicted_words, _ = model.transcribe_batch(
#         normalized.unsqueeze(0),
#         rel_length,
#     )

#     normalized = normalized.detach()
#     rel_length = rel_length.detach()
#     torch.cuda.empty_cache()

#     rowdf = pd.DataFrame({
#         'filename': row['RutaArchivo'],
#         'Duration': row['Duracion'],
#         'Text': " ".join(predicted_words),
#     }, index=pd.Index([0]))

#     traindf = pd.concat([traindf, rowdf], ignore_index=True)

# traindf

# %%
# columna = "Text"
# # Contar los registros vacíos en la columna
# num_vacios = traindf[columna].eq('').sum()
# # Calcular el total de registros en la columna
# total_registros = traindf[columna].shape[0]

# # Calcular el porcentaje de registros vacíos
# porcentaje_vacios = (num_vacios / total_registros) * 100
# # Imprimir los resultados
# print("Número de valores vacíos en la columna {}: {}".format(columna, num_vacios))
# print("Total de registros en la columna {}: {}".format(columna, total_registros))
# print("Porcentaje de valores vacíos en la columna {}: {:.2f}%".format(columna, porcentaje_vacios))

# %%
# traindf.to_excel(r'D:\sentirobots\Audios para pruebas\transcripcion-SpeechBrain.xlsx', index=False)
# print("Realizado")

# %%
import speech_recognition as sr
from langdetect import detect
import pandas as pd

def detect_language(audio_file):
    recognizer = sr.Recognizer()
    with sr.AudioFile(audio_file) as source:
        audio = recognizer.record(source)

    try:
        transcript = recognizer.recognize_google(audio)
        language = detect(transcript)
        
        return language
    except sr.UnknownValueError:
        print("No se pudo realizar la transcripción del audio.")
    except sr.RequestError as e:
        print(f"Error en la solicitud de reconocimiento de voz: {e}")


columna_ruta = "RutaArchivo"
df_copia = df.copy()
df_copia['IdiomaDetectado'] = df_copia[columna_ruta].apply(detect_language)
df_copia
# Out:
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# No se pudo realizar la transcripción del audio.
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# No se pudo realizar la transcripción del audio.
# Error en la solicitud de reconocimiento de voz: recognition request failed: Bad Request
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\http\client.py:556, in HTTPResponse._get_chunk_left(self)
#     555 try:
# --> 556     chunk_left = self._read_next_chunk_size()
#     557 except ValueError:
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:523, in HTTPResponse._read_next_chunk_size(self)
#     522 try:
# --> 523     return int(line, 16)
#     524 except ValueError:
#     525     # close the connection as protocol synchronisation is
#     526     # probably lost
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\http\client.py:573, in HTTPResponse._readall_chunked(self)
#     572 while True:
# --> 573     chunk_left = self._get_chunk_left()
#     574     if chunk_left is None:
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:558, in HTTPResponse._get_chunk_left(self)
#     557 except ValueError:
# --> 558     raise IncompleteRead(b'')
#     559 if chunk_left == 0:
#     560     # last chunk: 1*("0") [ chunk-extension ] CRLF
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# Cell In[9], line 35
#      32 df_copia = df.copy()
#      34 # Agregar una nueva columna al DataFrame copiado para almacenar el idioma detectado
# ---> 35 df_copia['IdiomaDetectado'] = df_copia[columna_ruta].apply(detect_language)
#      37 # Imprimir el DataFrame copiado con la nueva columna
#      38 df_copia
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[9], line 16, in detect_language(audio_file)
#      12     audio = recognizer.record(source)
#      14 try:
#      15     # Realizar la transcripción de la voz utilizando SpeechRecognition
# ---> 16     transcript = recognizer.recognize_google(audio)
#      18     # Detectar el idioma de la transcripción utilizando langdetect
#      19     language = detect(transcript)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\speech_recognition\__init__.py:713, in Recognizer.recognize_google(self, audio_data, key, language, pfilter, show_all, with_confidence)
#     711 except URLError as e:
#     712     raise RequestError("recognition connection failed: {}".format(e.reason))
# --> 713 response_text = response.read().decode("utf-8")
#     715 # ignore any blank blocks
#     716 actual_result = []
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     461 else:
#     462     # Amount is not given (unbounded read) so we must check self.length
#     463     # and self.chunked
#     465     if self.chunked:
# --> 466         return self._readall_chunked()
#     468     if self.length is None:
#     469         s = self.fp.read()
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:580, in HTTPResponse._readall_chunked(self)
#     578     return b''.join(value)
#     579 except IncompleteRead:
# --> 580     raise IncompleteRead(b''.join(value))
#
# IncompleteRead: IncompleteRead(14 bytes read)

# %%
#df_copia.to_excel(r'D:\sentirobots\CSV de carpeta audios para pruebas\pruebaIDIOMAS-SOLO-AUDIOS-MAFW.xlsx', index=False)
#print("idiomas detectados realizado neeneneeeeeeeeee")
