# %%
import pandas as pd
import speech_recognition as sr

# %%
def transcripcion(audio_path):
    r = sr.Recognizer()
    with sr.AudioFile(audio_path) as source:
        # Cargar el audio en el objeto Recognizer
        audio = r.record(source)
        try:
            #Google Speech Recognition para realizar la transcripción
            text = r.recognize_google(audio)
            return text
        except sr.UnknownValueError:
            print("No se pudo reconocer el audio")
            return ""
        except sr.RequestError as e:
            print("Error al hacer la solicitud al servicio de reconocimiento de voz: ", e)
            return ""

# %%
df = pd.read_csv(r'D:\sentirobots\Datasets\AffWild2\Filtro de audios - AffWild2\filtro-audio-AffWild2.csv')
df['Transcripcion'] = ''
df
# Out:
#                                            RutaArchivo        Nombre archivo  \
# 0    D:\sentirobots\Datasets\AffWild2\audios\audiob...     1-30-1280x720.wav
# 1    D:\sentirobots\Datasets\AffWild2\audios\audiob...    10-60-1280x720.wav
# 2    D:\sentirobots\Datasets\AffWild2\audios\audiob...  100-29-1080x1920.wav
# 3    D:\sentirobots\Datasets\AffWild2\audios\audiob...  101-30-1080x1920.wav
# 4    D:\sentirobots\Datasets\AffWild2\audios\audiob...    102-30-640x360.wav
# ..                                                 ...                   ...
# 543  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video92.wav
# 544  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video93.wav
# 545  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video94.wav
# 546  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video95.wav
# 547  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video96.wav
#
#      duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0     345.195          -20.411963   -2.643825                  46.602885
# 1      83.360          -29.514265  -10.816923                  39.451079
# 2      88.027          -22.144754   -0.380093                  36.622090
# 3     171.897          -22.307136   -1.578749                  40.574282
# 4      99.567          -31.040582  -11.640265                  41.151479
# ..        ...                 ...         ...                        ...
# 543    85.078          -27.134215   -9.677598                  40.793541
# 544    14.861          -28.762329   -3.323837                  24.828388
# 545    23.197                -inf        -inf                        NaN
# 546   361.813          -19.425846   -0.066522                  45.355111
# 547   268.190          -29.666974  -11.761591                  45.788321
#
#      Relación señal a ruido  Filtro  Falla en  Filtro2 Transcripcion
# 0                -26.025131       1         0        1
# 1                 -9.854546       1         0        1
# 2                 -9.284685       1         0        1
# 3                -12.797139       1         0        1
# 4                -15.240322       1         0        1
# ..                      ...     ...       ...      ...           ...
# 543              -13.671058       1         0        1
# 544               -5.914669       0         1        1
# 545                     NaN       0         2        0
# 546               -9.757145       1         0        1
# 547               -8.806558       1         0        1
#
# [548 rows x 11 columns]

# %%
cont=0
for index, row in df.iterrows():
    if row['Filtro2'] == 1:
        cont=cont+1
        print(cont)
        ruta_archivo = row['RutaArchivo']
        transcripcion_audio = transcripcion(ruta_archivo)
        df.at[index, 'Transcripcion'] = transcripcion_audio
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# No se pudo reconocer el audio
# 7
# 8
# No se pudo reconocer el audio
# 9
# 10
# No se pudo reconocer el audio
# 11
# 12
# 13
# No se pudo reconocer el audio
# 14
# 15
# 16
# 17
# 18
# 19
# No se pudo reconocer el audio
# 20
# 21
# 22
# No se pudo reconocer el audio
# 23
# 24
# 25
# 26
# No se pudo reconocer el audio
# 27
# 28
# 29
# 30
# 31
# No se pudo reconocer el audio
# 32
# 33
# No se pudo reconocer el audio
# 34
# 35
# 36
# 37
# 38
# 39
# 40
# No se pudo reconocer el audio
# 41
# 42
# 43
# 44
# 45
# 46
# Error al hacer la solicitud al servicio de reconocimiento de voz:  recognition request failed: Bad Request
# 47
# 48
# 49
# No se pudo reconocer el audio
# 50
# 51
# No se pudo reconocer el audio
# 52
# 53
# 54
# 55
# 56
# 57
# No se pudo reconocer el audio
# 58
# 59
# 60
# 61
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# No se pudo reconocer el audio
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# No se pudo reconocer el audio
# 83
# 84
# 85
# 86
# No se pudo reconocer el audio
# 87
# No se pudo reconocer el audio
# 88
# 89
# 90
# 91
# No se pudo reconocer el audio
# 92
# 93
# 94
# 95
# 96
# 97
# No se pudo reconocer el audio
# 98
# 99
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# No se pudo reconocer el audio
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# No se pudo reconocer el audio
# 121
# 122
# 123
# 124
# 125
# No se pudo reconocer el audio
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# No se pudo reconocer el audio
# 137
# 138
# No se pudo reconocer el audio
# 139
# No se pudo reconocer el audio
# 140
# 141
# 142
# No se pudo reconocer el audio
# 143
# No se pudo reconocer el audio
# 144
# 145
# 146
# 147
# 148
# No se pudo reconocer el audio
# 149
# No se pudo reconocer el audio
# 150
# 151
# 152
# 153
# 154
# 155
# No se pudo reconocer el audio
# 156
# 157
# No se pudo reconocer el audio
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# No se pudo reconocer el audio
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# No se pudo reconocer el audio
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# No se pudo reconocer el audio
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# No se pudo reconocer el audio
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# No se pudo reconocer el audio
# 212
# 213
# 214
# 215
# 216
# 217
# No se pudo reconocer el audio
# 218
# 219
# No se pudo reconocer el audio
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# No se pudo reconocer el audio
# 227
# 228
# 229
# 230
# No se pudo reconocer el audio
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# No se pudo reconocer el audio
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# No se pudo reconocer el audio
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# No se pudo reconocer el audio
# 290
# 291
# 292
# 293
# 294
# 295
# No se pudo reconocer el audio
# 296
# 297
# 298
# 299
# 300
# No se pudo reconocer el audio
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# No se pudo reconocer el audio
# 311
# 312
# 313
# 314
# 315
# No se pudo reconocer el audio
# 316
# 317
# 318
# No se pudo reconocer el audio
# 319
# 320
# No se pudo reconocer el audio
# 321
# No se pudo reconocer el audio
# 322
# 323
# No se pudo reconocer el audio
# 324
# 325
# No se pudo reconocer el audio
# 326
# 327
# No se pudo reconocer el audio
# 328
# No se pudo reconocer el audio
# 329
# 330
# No se pudo reconocer el audio
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# No se pudo reconocer el audio
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# No se pudo reconocer el audio
# 345
# No se pudo reconocer el audio
# 346
# 347
# No se pudo reconocer el audio
# 348
# 349
# 350
# 351
# 352
# No se pudo reconocer el audio
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# No se pudo reconocer el audio
# 370
# 371
# 372
# No se pudo reconocer el audio
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# No se pudo reconocer el audio
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# No se pudo reconocer el audio
# 407
# No se pudo reconocer el audio
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# No se pudo reconocer el audio
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# Error al hacer la solicitud al servicio de reconocimiento de voz:  recognition request failed: Bad Request
# 429
# 430
# 431
# No se pudo reconocer el audio
# 432
# 433
# No se pudo reconocer el audio
# 434
# 435
# 436
# 437
# 438
# No se pudo reconocer el audio
# 439
# 440
# No se pudo reconocer el audio
# 441
# 442
# No se pudo reconocer el audio
# 443
# 444
# 445
# 446
# 447
# No se pudo reconocer el audio
# 448
# 449
# No se pudo reconocer el audio
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# No se pudo reconocer el audio
# 460
# No se pudo reconocer el audio
# 461
# 462
# 463
# 464
# 465
# No se pudo reconocer el audio
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
# 480
# 481
# No se pudo reconocer el audio
# 482
# No se pudo reconocer el audio
# 483
# No se pudo reconocer el audio
# 484
# No se pudo reconocer el audio
# 485
# No se pudo reconocer el audio
# 486
# No se pudo reconocer el audio
# 487
# No se pudo reconocer el audio
# 488
# 489
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# No se pudo reconocer el audio
# 499
# 500
# No se pudo reconocer el audio
# 501
# No se pudo reconocer el audio
# 502
# 503
# No se pudo reconocer el audio
# 504
# No se pudo reconocer el audio
# 505
# 506
# 507
# 508
# 509
# 510
# No se pudo reconocer el audio
# 511
# 512
# 513
# 514
# 515
# 516
# No se pudo reconocer el audio
# 517
# 518
# 519
# 520
# 521
# 522
# 523
# 524
# 525
# No se pudo reconocer el audio
# 526
# 527
# 528
# 529
# 530
# 531
# 532
# 533

# %%
df
# Out:
#                                            RutaArchivo        Nombre archivo  \
# 0    D:\sentirobots\Datasets\AffWild2\audios\audiob...     1-30-1280x720.wav
# 1    D:\sentirobots\Datasets\AffWild2\audios\audiob...    10-60-1280x720.wav
# 2    D:\sentirobots\Datasets\AffWild2\audios\audiob...  100-29-1080x1920.wav
# 3    D:\sentirobots\Datasets\AffWild2\audios\audiob...  101-30-1080x1920.wav
# 4    D:\sentirobots\Datasets\AffWild2\audios\audiob...    102-30-640x360.wav
# ..                                                 ...                   ...
# 543  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video92.wav
# 544  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video93.wav
# 545  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video94.wav
# 546  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video95.wav
# 547  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video96.wav
#
#      duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0     345.195          -20.411963   -2.643825                  46.602885
# 1      83.360          -29.514265  -10.816923                  39.451079
# 2      88.027          -22.144754   -0.380093                  36.622090
# 3     171.897          -22.307136   -1.578749                  40.574282
# 4      99.567          -31.040582  -11.640265                  41.151479
# ..        ...                 ...         ...                        ...
# 543    85.078          -27.134215   -9.677598                  40.793541
# 544    14.861          -28.762329   -3.323837                  24.828388
# 545    23.197                -inf        -inf                        NaN
# 546   361.813          -19.425846   -0.066522                  45.355111
# 547   268.190          -29.666974  -11.761591                  45.788321
#
#      Relación señal a ruido  Filtro  Falla en  Filtro2  \
# 0                -26.025131       1         0        1
# 1                 -9.854546       1         0        1
# 2                 -9.284685       1         0        1
# 3                -12.797139       1         0        1
# 4                -15.240322       1         0        1
# ..                      ...     ...       ...      ...
# 543              -13.671058       1         0        1
# 544               -5.914669       0         1        1
# 545                     NaN       0         2        0
# 546               -9.757145       1         0        1
# 547               -8.806558       1         0        1
#
#                                          Transcripcion
# 0    waving hands like clouds let's begin. Or raisi...
# 1    Norman and I Norman Reedus who plays Daryl Dix...
# 2    what does y e s spell what does e y e s spell ...
# 3            what is a y e s l e y e s l e y e s spell
# 4                                            Opelousas
# ..                                                 ...
# 543  which city are grappling with the evils of ter...
# 544                                 show me a map face
# 545
# 546  hi I'm Terry Crews and I'm doing the wired aut...
# 547  thank you thank you thank you thank you very m...
#
# [548 rows x 11 columns]

# %%
df.describe()
# Out:
#           duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# count   548.000000          548.000000  548.000000                 540.000000
# mean    168.640462                -inf        -inf                  39.550236
# std     133.572034                 NaN         NaN                   5.505709
# min       2.624000                -inf        -inf                  11.494956
# 25%      96.502250          -28.564795   -6.398478                  36.042507
# 50%     144.046500          -24.158045   -1.474627                  39.884940
# 75%     195.496250          -19.626403    0.000000                  43.067194
# max    1581.000000          -10.504903    0.000000                  53.910710
#
#        Relación señal a ruido      Filtro    Falla en     Filtro2
# count              540.000000  548.000000  548.000000  548.000000
# mean               -13.843661    0.945255    0.074818    0.972628
# std                  6.116763    0.227689    0.331007    0.163315
# min                -39.997880    0.000000    0.000000    0.000000
# 25%                -16.882705    1.000000    0.000000    1.000000
# 50%                -12.233776    1.000000    0.000000    1.000000
# 75%                 -9.840232    1.000000    0.000000    1.000000
# max                 -1.739952    1.000000    2.000000    1.000000

# %%
columna = "Transcripcion"
c= "Filtro2"

num_vacios = df[columna].eq('').sum()
num_ceros = df[c].eq(0).sum()
total_registros = df[columna].shape[0]
porcentaje_vacios = (num_vacios / total_registros) * 100
p_ceros= (num_ceros / total_registros) * 100


print("Número de valores vacíos en la columna {}: {}".format(columna, num_vacios))
print("Total de registros en la columna {}: {}".format(columna, total_registros))
print("Porcentaje de valores vacíos en la columna {}: {:.2f}%".format(columna, porcentaje_vacios))


print("Número de valores 0s en la columna {}: {}".format(c, num_ceros))
print("Total de registros en la columna {}: {}".format(c, total_registros))
print("Porcentaje de valores 0s en la columna {}: {:.2f}%".format(c, p_ceros))
# Out:
# Número de valores vacíos en la columna Transcripcion: 108
# Total de registros en la columna Transcripcion: 548
# Porcentaje de valores vacíos en la columna Transcripcion: 19.71%
# Número de valores 0s en la columna Filtro2: 15
# Total de registros en la columna Filtro2: 548
# Porcentaje de valores 0s en la columna Filtro2: 2.74%

# %% [markdown]
# # Limpieza del texto

# %%
df['Transcripcion2'] = ''
#df['Coherencia'] = ''
#df['Gramatica'] = ''
df
# Out:
#                                            RutaArchivo        Nombre archivo  \
# 0    D:\sentirobots\Datasets\AffWild2\audios\audiob...     1-30-1280x720.wav
# 1    D:\sentirobots\Datasets\AffWild2\audios\audiob...    10-60-1280x720.wav
# 2    D:\sentirobots\Datasets\AffWild2\audios\audiob...  100-29-1080x1920.wav
# 3    D:\sentirobots\Datasets\AffWild2\audios\audiob...  101-30-1080x1920.wav
# 4    D:\sentirobots\Datasets\AffWild2\audios\audiob...    102-30-640x360.wav
# ..                                                 ...                   ...
# 543  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video92.wav
# 544  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video93.wav
# 545  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video94.wav
# 546  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video95.wav
# 547  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video96.wav
#
#      duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0     345.195          -20.411963   -2.643825                  46.602885
# 1      83.360          -29.514265  -10.816923                  39.451079
# 2      88.027          -22.144754   -0.380093                  36.622090
# 3     171.897          -22.307136   -1.578749                  40.574282
# 4      99.567          -31.040582  -11.640265                  41.151479
# ..        ...                 ...         ...                        ...
# 543    85.078          -27.134215   -9.677598                  40.793541
# 544    14.861          -28.762329   -3.323837                  24.828388
# 545    23.197                -inf        -inf                        NaN
# 546   361.813          -19.425846   -0.066522                  45.355111
# 547   268.190          -29.666974  -11.761591                  45.788321
#
#      Relación señal a ruido  Filtro  Falla en  Filtro2  \
# 0                -26.025131       1         0        1
# 1                 -9.854546       1         0        1
# 2                 -9.284685       1         0        1
# 3                -12.797139       1         0        1
# 4                -15.240322       1         0        1
# ..                      ...     ...       ...      ...
# 543              -13.671058       1         0        1
# 544               -5.914669       0         1        1
# 545                     NaN       0         2        0
# 546               -9.757145       1         0        1
# 547               -8.806558       1         0        1
#
#                                          Transcripcion Transcripcion2
# 0    waving hands like clouds let's begin. Or raisi...
# 1    Norman and I Norman Reedus who plays Daryl Dix...
# 2    what does y e s spell what does e y e s spell ...
# 3            what is a y e s l e y e s l e y e s spell
# 4                                            Opelousas
# ..                                                 ...            ...
# 543  which city are grappling with the evils of ter...
# 544                                 show me a map face
# 545
# 546  hi I'm Terry Crews and I'm doing the wired aut...
# 547  thank you thank you thank you thank you very m...
#
# [548 rows x 12 columns]

# %%
import re
import emoji

def quitar_caracteres_especiales(texto):
    patron = r'[^\w\s?!.,:;\'"]'
    texto_sin_especiales = re.sub(patron, '', texto)
    texto_sin_emojis = emoji.demojize(texto_sin_especiales)
    patron = re.compile(r':[^:\s]*(?:::[^:\s]*)*:')
    texto_limpio = re.sub(patron, '', texto_sin_emojis)    
    return texto_limpio
#texto = "¡Hola, @usuario! ¿Cómo estás? #Python es genial!!! Me dijo: Cómo te llamas; luego de comer😃🚀"
#clean_text = quitar_caracteres_especiales(texto)
#print(clean_text)

# %%
#conta=0
for index, row in df.iterrows():
    if row['Filtro2'] == 1:
        #conta=conta+1
        #print(conta)
        texto = row['Transcripcion']
        clean_text = quitar_caracteres_especiales(texto)
        #coherencia = detectar_coherencia(texto)
        #errores_gramaticales = detectar_errores_gramaticales(texto)
        df.at[index, 'Transcripcion2'] = clean_text
        #df.at[index, 'Coherencia'] = coherencia
        #df.at[index, 'Gramatica'] = errores_gramaticales

# %%
df
# Out:
#                                            RutaArchivo        Nombre archivo  \
# 0    D:\sentirobots\Datasets\AffWild2\audios\audiob...     1-30-1280x720.wav
# 1    D:\sentirobots\Datasets\AffWild2\audios\audiob...    10-60-1280x720.wav
# 2    D:\sentirobots\Datasets\AffWild2\audios\audiob...  100-29-1080x1920.wav
# 3    D:\sentirobots\Datasets\AffWild2\audios\audiob...  101-30-1080x1920.wav
# 4    D:\sentirobots\Datasets\AffWild2\audios\audiob...    102-30-640x360.wav
# ..                                                 ...                   ...
# 543  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video92.wav
# 544  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video93.wav
# 545  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video94.wav
# 546  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video95.wav
# 547  D:\sentirobots\Datasets\AffWild2\audios\audiob...           video96.wav
#
#      duracion  Promedio level pot  Nivel peak  Distorsión armónica total  \
# 0     345.195          -20.411963   -2.643825                  46.602885
# 1      83.360          -29.514265  -10.816923                  39.451079
# 2      88.027          -22.144754   -0.380093                  36.622090
# 3     171.897          -22.307136   -1.578749                  40.574282
# 4      99.567          -31.040582  -11.640265                  41.151479
# ..        ...                 ...         ...                        ...
# 543    85.078          -27.134215   -9.677598                  40.793541
# 544    14.861          -28.762329   -3.323837                  24.828388
# 545    23.197                -inf        -inf                        NaN
# 546   361.813          -19.425846   -0.066522                  45.355111
# 547   268.190          -29.666974  -11.761591                  45.788321
#
#      Relación señal a ruido  Filtro  Falla en  Filtro2  \
# 0                -26.025131       1         0        1
# 1                 -9.854546       1         0        1
# 2                 -9.284685       1         0        1
# 3                -12.797139       1         0        1
# 4                -15.240322       1         0        1
# ..                      ...     ...       ...      ...
# 543              -13.671058       1         0        1
# 544               -5.914669       0         1        1
# 545                     NaN       0         2        0
# 546               -9.757145       1         0        1
# 547               -8.806558       1         0        1
#
#                                          Transcripcion  \
# 0    waving hands like clouds let's begin. Or raisi...
# 1    Norman and I Norman Reedus who plays Daryl Dix...
# 2    what does y e s spell what does e y e s spell ...
# 3            what is a y e s l e y e s l e y e s spell
# 4                                            Opelousas
# ..                                                 ...
# 543  which city are grappling with the evils of ter...
# 544                                 show me a map face
# 545
# 546  hi I'm Terry Crews and I'm doing the wired aut...
# 547  thank you thank you thank you thank you very m...
#
#                                         Transcripcion2
# 0    waving hands like clouds let's begin. Or raisi...
# 1    Norman and I Norman Reedus who plays Daryl Dix...
# 2    what does y e s spell what does e y e s spell ...
# 3            what is a y e s l e y e s l e y e s spell
# 4                                            Opelousas
# ..                                                 ...
# 543  which city are grappling with the evils of ter...
# 544                                 show me a map face
# 545
# 546  hi I'm Terry Crews and I'm doing the wired aut...
# 547  thank you thank you thank you thank you very m...
#
# [548 rows x 12 columns]
